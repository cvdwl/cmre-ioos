# %%
import numpy as np
import seawater as sw
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
import netCDF4
import numpy.ma as ma
import seawater
# %matplotlib inline
import iris

# %%
url = 'GL-20140621-elettra-MEDREP14depl005-grid-R.nc'
url = 'GL-20140620-jade-MEDREP14depl005-grid-R.nc'
url = 'GL-20140620-wtd71-MEDREP14depl005-grid-R.nc'
url = 'http://scsrv26v:8080/thredds/dodsC/models/geos3/REP14/data/NURC/gliders/noa/GL-20140609-noa-MEDREP14depl001-grid-D.nc'
url = 'http://scsrv26v:8080/thredds/dodsC/models/geos3/REP14/data/NURC/gliders/ncml/GL-20140608-zoe-MEDREP14depl001-grid-D.nc.ncml'

# %%
tvar = iris.load_cube(url,'sea_water_potential_temperature')
print tvar
# Out:
# sea_water_potential_temperature / (Celsius) (-- : 1008; -- : 169)
#      Auxiliary coordinates:
#           latitude                              x          -
#           longitude                             x          -
#           time                                  x          -
#           depth                                 -          x
#      Attributes:
#           Conventions: CF-1.6
#           DODS.dimName: ocrProfile
#           DODS.strlen: 1008
#           QC_indicator: 0.0
#           anomaly: none
#           cdm_data_type: trajectoryProfile
#           contact: http://www.cmre.nato.int/
#           cruise: MEDREP14
#           data_classification: NATO Unclassified
#           data_mode: D
#           data_type: Glider profiles data
#           date_update: 2014-07-02T19:41:28Z
#           disclaimer: The processing software that generated this dataset is under development....
#           distribution_statement: NATO UNCLASSIFIED releasable to project partner only
#           featureType: trajectoryProfile
#           format_version: 0.99
#           geospatial_lat_max: 39.5798149203
#           geospatial_lat_min: 39.455782985
#           geospatial_lon_max: 8.29002727343
#           geospatial_lon_min: 7.25698324743
#           geospatial_vertical_max: 176.0
#           geospatial_vertical_min: 0.0
#           history: 2014-07-02 19:41:28: File created
#           institution: STO-CMRE
#           institution_reference: http://www.cmre.nato.int/
#           launch_date: 08-Jun-2014 08:30:00
#           launch_latitude: 39.5156828085
#           launch_longitude: 8.25122369756
#           launch_qc: 0.0
#           mission: depl001
#           netcdf_version: 3.6
#           pi_name: R. Onken
#           platform_code: zoe
#           platform_maker: Teledyne Webb Research Corporation
#           platform_model: WEBB SLOCUM
#           positioning_system: GPS
#           processing: post processing
#           product_description: This file contains a glider data product derived from processed data. Trajectory...
#           project_name: MEDREP14
#           provider: STO-CMRE (NATO Science & Technology Organization - Centre for Maritime...
#           qcCodes: 0: no quality control performed on that value; 1: good value (GPS fix);...
#           qc_manual: http://www.groom.org/data/quality_control_manual.pdf
#           quality_index: 0.0
#           references: http://geos3.cmre.nato.int/REP14
#           sensors_bbfl2s_backscatter_wavelength: 532nm
#           sensors_bbfl2s_bb_cwo: 58 (clean water offset)
#           sensors_bbfl2s_bb_sf: 8.485 e-6 (scale factor)
#           sensors_bbfl2s_cdom_cwo: 55 (clean water offset)
#           sensors_bbfl2s_cdom_ex_em: 370/460nm
#           sensors_bbfl2s_cdom_sf: 0.0913 ppb/count (scale factor)
#           sensors_bbfl2s_chlor_cwo: 45 (clean water offset)
#           sensors_bbfl2s_chlor_sf: 0.0121 ug/l/count (scale factor)
#           sensors_bbfl2s_chlorophyll_ex_em: 470/695nm
#           sensors_bbfl2s_manufacturer: Wet Labs
#           sensors_bbfl2s_model: ECO Triplet
#           sensors_bbfl2s_name: Fluorometer and backscatter
#           sensors_bbfl2s_serial_number: 1112.0
#           sensors_ctd_manufacturer: Seabird
#           sensors_ctd_model: SBE41CP
#           sensors_ctd_name: unpumpedCTD
#           sensors_ctd_serial_number: 151.0
#           sensors_ocr504i_Vin_a0: 0.0 (polynomial coefficient to scale Vin)
#           sensors_ocr504i_Vin_a1: 0.03 (polynomial coefficient to scale Vin)
#           sensors_ocr504i_cal_coeff_c1: 1849533.25875 e-13 (calibration factor for channel 1)
#           sensors_ocr504i_cal_coeff_c2: 1856315.27267 e-13 (calibration factor for channel 2)
#           sensors_ocr504i_cal_coeff_c3: 2317837.52483 e-13 (calibration factor for channel 3)
#           sensors_ocr504i_cal_coeff_c4: 1991091.28953 e-13 (calibration factor for channel 4)
#           sensors_ocr504i_dark_counts_c1: 2149122498.5 (dark offset for channel 1)
#           sensors_ocr504i_dark_counts_c2: 2147468320.4 (dark offset for channel 2)
#           sensors_ocr504i_dark_counts_c3: 2147942587.9 (dark offset for channel 3)
#           sensors_ocr504i_dark_counts_c4: 2147211902.8 (dark offset for channel 4)
#           sensors_ocr504i_immersion_coeff_c1: 1.368 (immersion factor for channel1)
#           sensors_ocr504i_immersion_coeff_c2: 1.410 (immersion factor for channel2)
#           sensors_ocr504i_immersion_coeff_c3: 1.365 (immersion factor for channel3)
#           sensors_ocr504i_immersion_coeff_c4: 1.372 (immersion factor for channel4)
#           sensors_ocr504i_itemp_a0: -50.0 (polynomial coefficient to scale itemp)
#           sensors_ocr504i_itemp_a1: 0.5 (polynomial coefficient to scale itemp)
#           sensors_ocr504i_manufacturer: Satlantic
#           sensors_ocr504i_model: AUV OCR-504ICSW
#           sensors_ocr504i_name: Multispectral Radiometer
#           sensors_ocr504i_serial_number: 161.0
#           sensors_ocr504i_wavelengths: 411.7 443.6 490.9 554.7 nm
#           source: Glider observation
#           summary: MEDREP14 glider data. Zoe is a Slocum near-surface glider.
#           time_coverage_end: 2014-06-23T03:44:41Z
#           time_coverage_start: 2014-06-08T09:19:05Z
#           title: MEDREP14 Zoe Glider full deployment
#           trans_system: IRIDIUM
#           type: Glider data file
#           update_interval: void

# %%
nc = netCDF4.Dataset(url)

# %%
ncv = nc.variables

# %%
ncv.keys()
# Out:
# [u'bbfl2s_latitude',
#  u'bbfl2s_longitude',
#  u'bbfl2s_distance',
#  u'bbfl2s_time',
#  u'bbfl2s_profileDir',
#  u'bbfl2s_depth',
#  u'ctd_latitude',
#  u'ctd_longitude',
#  u'ctd_distance',
#  u'ctd_time',
#  u'ctd_profileDir',
#  u'ctd_depth',
#  u'bbfl2s_backscattering',
#  u'bbfl2s_cdom',
#  u'bbfl2s_chlorophyl',
#  u'ctd_cond',
#  u'ctd_pden',
#  u'ctd_pres',
#  u'ctd_ptmp',
#  u'ctd_salt',
#  u'ctd_svel',
#  u'ctd_temp']

# %%
print ncv['ctd_temp']
# Out:
# <type 'netCDF4.Variable'>
# float64 ctd_temp(ctdProfile, ctdDepth)
#     long_name: water temperature
#     standard_name: sea_water_temperature
#     units: Celsius
#     _FillValue: -1000000.0
#     QC_indicator: 0.0
# unlimited dimensions:
# current shape = (500, 881)
# filling off

# %%
lon = ncv['ctd_longitude'][:]
lat = ncv['ctd_latitude'][:]
z = ncv['ctd_depth'][:]
tvar = ncv['ctd_time']
tim = netCDF4.num2date(tvar[:],tvar.units)

# %%
data = ncv['ctd_temp'][:]

# %%
print ncv['ctd_temp']
# Out:
# <type 'netCDF4.Variable'>
# float64 ctd_temp(ctdProfile, ctdDepth)
#     long_name: water temperature
#     standard_name: sea_water_temperature
#     units: Celsius
#     _FillValue: -1000000.0
#     QC_indicator: 0.0
# unlimited dimensions:
# current shape = (500, 881)
# filling off

# %%
data = ma.masked_invalid(data,copy=True)
z = ma.masked_invalid(z,copy=True)

# %%
data.min()
# Out:
# 12.991396576514269

# %%
dist, pha = sw.dist(lat, lon, units='km')

# %%
dist.min()
# Out:
# 0.027703967986406595

# %%
def plot_glider(lon,lat,z,tim, data, mask_topo=False, **kw):
    """Plot glider cube."""
    cmap = kw.pop('cmap', plt.cm.rainbow)
    
    
    dist, pha = sw.dist(lat, lon, units='km')
    dist = np.append(0, np.cumsum(dist))
    dist, z = np.broadcast_arrays(dist[..., None], z)
    """
    z_range = [z.min(), z.max()]
    data_range = [data.min(), data.max()]
    good = np.logical_and(data >= data_range[0], data <= data_range[1])
    data = ma.masked_where(~good, data)
    
    condition = np.logical_and(z >= z_range[0], z <= z_range[1])
    z = ma.masked_where(~condition, z)
    """   
    fig,ax = plt.subplots(figsize=(12,4))
    cs = ax.pcolor(dist, z, data, cmap=cmap, **kw)

    if mask_topo:
        h = z.max(axis=1)
        xm, hm = gen_topomask(h, lon, lat, dx=1., kind='linear')
        ax.plot(xm, hm, color='black', linewidth='1', zorder=3)
        ax.fill_between(xm, hm, y2=hm.max(), color='0.8', zorbathy_der=3)
    ax.invert_yaxis()
    ax.set_title('Glider track from {} to {}'.format(tim[0], tim[-1]))
    ax.set_ylabel('depth (m)')
    ax.set_xlabel('alongtrack distance (km)')

    return fig, ax, cs, dist

# %%
fig, ax, cs, dist= plot_glider(lon,lat,z,tim,data, mask_topo=False)
plt.ylim((0,100))
ax.invert_yaxis()
plt.colorbar(cs)
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x7f65c97704d0>

# %%
t = iris.load_cube(url,'sea_water_temperature')
# Out:
# /usr/local/anaconda/lib/python2.7/site-packages/iris/fileformats/_pyke_rules/compiled_krb/fc_rules_cf_fc.py:1196: UserWarning: Ignoring netCDF variable 'ctd_pden' invalid units 'Kg m-3'
#   warnings.warn(msg.format(msg_name, msg_units))

# %%
plt.plot(dist);

# %%
bathy_url='http://geoport.whoi.edu/thredds/dodsC/bathy/srtm30plus_v1.nc'

# %%
url='http://geoport.whoi.edu/thredds/dodsC/bathy/crm_vol1.nc'
# Test Latitude coordinate increasing:
#url='http://geoport.whoi.edu/thredds/dodsC/bathy/etopo1_bed_g2'
# Test failure because lat is not uniformly spaced:
#url='http://geoport.whoi.edu/thredds/dodsC/bathy/smith_sandwell_v11'
box = [-71.4,41,-70.2,42]
#box=[-71.0,41.0,-67.0,46.0]
box = [lon.min(), lat.min(), lon.max(), lat.max()]

# %%
def get_bathy(url,box):
    nc=netCDF4.Dataset(url)
    print "Source name: %s" % nc.title
    lon=nc.variables['lon'][:]
    lat=nc.variables['lat'][:]
    bi=(lon>=box[0])&(lon<=box[2])
    bj=(lat>=box[1])&(lat<=box[3])
    z=nc.variables['topo'][bj,bi]
    nc.close()
    lon=lon[bi]
    lat=lat[bj]
    return z,lon,lat

# %%
bathy_z, bathy_lon, bathy_lat = get_bathy(bathy_url,box)
fig = plt.figure(figsize=(6, 6))
ax = fig.add_axes([0.1, 0.15, 0.8, 0.8])
pc = ax.pcolormesh(bathy_lon,bathy_lat, bathy_z,
                   vmin=bathy_z.min(), vmax=0,
                   cmap=plt.cm.RdBu_r)
cbax = fig.add_axes([0.1, 0.08, 0.8, 0.02])
cb = plt.colorbar(pc, cax=cbax, 
                  orientation='horizontal')
cb.set_label('Depth [m]')
ax.set_aspect(1.0/np.cos(bathy_lat.min() * np.pi / 180.0))
# Out:
# Source name: UCSD SRTM30_v1 Global DEM (30 sec)
# /usr/local/anaconda/lib/python2.7/site-packages/matplotlib/axes/_base.py:1039: UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   if aspect == 'normal':
# /usr/local/anaconda/lib/python2.7/site-packages/matplotlib/axes/_base.py:1044: UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   elif aspect in ('equal', 'auto'):
